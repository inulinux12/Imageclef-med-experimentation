# %% [markdown]
# # Disease experimentation

# %% [markdown]
# ## Dataset

# %% [markdown]
# Proceso para generar el dataset.
# Para generar el dataset sobre diseases se escogieron los conceptos que se encontraban bajo la jerarquía de disease, se seleccionaron los artículos que fueron anotados por estos conceptos y se reanotaron con los 81 conceptos directamente hijos de disease en la ontología. De los 81 solo se usaron 71 y la siguiente es la frecuencia de aparición por artículo de cada uno de los 71 conceptos.

# %%
import caffe
from IPython.display import display, Image
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# A continuación cargamos los conceptos extraidos de disease.

# %%
anotaciones = pd.read_csv("anotacionesdisease.csv")
conceptos = pd.read_csv("conceptosDiseases.csv")
anotaciones
# Out:
#        article_id  conceptId
# 0   pmid-22047519  413839001
# 1   pmid-20704731   73430006
# 2   pmid-20704731   12138000
# 3   pmid-20704731   78275009
# 4   pmid-19922685   62479008
# 5   pmid-20525146  233604007
# 6   pmid-20525146  106190000
# 7   pmid-20525146   72656004
# 8   pmid-20525146  233691007
# 9   pmid-18466605  386584007
# 10  pmid-17222328  230782004
# 11  pmid-18218115   73211009
# 12  pmid-21385374  312950007
# 13  pmid-21167080   42399005
# 14  pmid-21167080  236425005
# 15  pmid-15651992  106190000
# 16  pmid-15651992   41345002
# 17  pmid-15651992  230782004
# 18  pmid-20696065   19168005
# 19  pmid-12513699   75478009
# 20  pmid-16859512   89627008
# 21  pmid-19728864   71677004
# 22  pmid-19728864   55604004
# 23  pmid-17570159   90968009
# 24  pmid-16162287   71677004
# 25  pmid-19615098  248261008
# 26  pmid-21970639   69878008
# 27  pmid-21970639  129103003
# 28  pmid-21970639  237793004
# 29  pmid-20205899  129576003
# 30  pmid-20467566  415172002
# 31  pmid-20467566   24748008
# 32  pmid-21645423   64667001
# 33  pmid-21645423  200936003
# 34  pmid-21645423  239918008
# 35  pmid-16185359  413924001
# 36  pmid-16185359  230404004
# 37  pmid-21929778   49765009
# 38  pmid-21929778   34486009
# 39  pmid-21929778   36209000
# 40  pmid-20184780    7259005
# 41  pmid-20184780     378007
# 42  pmid-17961234   80394007
# 43  pmid-12946280   30911005
# 44  pmid-12946280  413603009
# 45  pmid-16207330   55464009
# 46  pmid-20226025   62479008
# 47  pmid-20226025  423997002
# 48  pmid-18803862  312991009
# 49  pmid-18803862    2776000
# 50  pmid-18803862   52448006
# 51  pmid-22085420  237498007
# 52  pmid-22085420   36976004
# 53  pmid-15663781  232448002
# 54  pmid-15663781   47004009
# 55  pmid-21943017  116223007
# 56  pmid-19946529   71419002
# 57  pmid-19772665   36166001
# 58  pmid-19772665  233604007
# 59  pmid-20043852   34095006
#               ...        ...
#
# [38233 rows x 2 columns]

# %%
conceptos
# Out:
#     Concept  ConceptProcessed
# 0    241006         123946008
# 1    317006         123946008
# 2    355001           2704003
# 3    378007         362975008
# 4    568005          74732009
# 5    596004          74732009
# 6    613003         281867008
# 7    626004         123946008
# 8    651003          74732009
# 9    832007          74732009
# 10   899001          74732009
# 11   934007         414022008
# 12  1145003           5294002
# 13  1207009         362975008
# 14  1212005         128139000
# 15  1271009         281867008
# 16  1376001          74732009
# 17  1388004          75934005
# 18  1426004         417163006
# 19  1482004         441457006
# 20  1488000         422400008
# 21  1493002           2704003
# 22  1498006         127326005
# 23  1515008         362975008
# 24  1519002          66091009
# 25  1563006         362970003
# 26  1648002         123946008
# 27  1654001          87858002
# 28  1685005          40733004
# 29  1717003         414032001
# 30  1767005         123946008
# 31  1776003          75934005
# 32  1829003         123946008
# 33  1845001         123946008
# 34  1847009         128139000
# 35  1855002           5294002
# 36  1899006          32895009
# 37  1926006          66091009
# 38  1963002         414022008
# 39  2032001         118654009
# 40  2065009          32895009
# 41  2103002         123946008
# 42  2107001         123946008
# 43  2229005          66091009
# 44  2391001          66091009
# 45  2403008          74732009
# 46  2470005         417163006
# 47  2492009           2492009
# 48  2538008          75934005
# 49  2593002         281867008
# 50  2694001         414022008
# 51  2707005         414025005
# 52  2751001          75934005
# 53  2772003         362975008
# 54  2776000          74732009
# 55  2829000          66091009
# 56  2858002          40733004
# 57  2897005         362970003
# 58  2904007         123946008
# 59  2919008         422400008
#         ...               ...
#
# [3852 rows x 2 columns]

# %% [markdown]
# A continuación se reemplazan los conceptos que jerarquicamente se encuentran bajo Disease y se reemplazan por los conceptos directamente hijos de Disease.

# %%
conceptos = conceptos.set_index('Concept')
anotaciones['conceptId'] = anotaciones['conceptId'].map(conceptos['ConceptProcessed'])
anotaciones = anotaciones.drop_duplicates(['article_id','conceptId'])
anotaciones
# Out:
#        article_id  conceptId
# 0   pmid-22047519   27624003
# 1   pmid-20704731   39898005
# 2   pmid-20704731  123946008
# 4   pmid-19922685   40733004
# 5   pmid-20525146  123946008
# 6   pmid-20525146  420134006
# 7   pmid-20525146  128139000
# 9   pmid-18466605  123946008
# 10  pmid-17222328  123946008
# 11  pmid-18218115   75934005
# 12  pmid-21385374  128139000
# 13  pmid-21167080  123946008
# 14  pmid-21167080   27624003
# 15  pmid-15651992  420134006
# 16  pmid-15651992   75934005
# 17  pmid-15651992  123946008
# 18  pmid-20696065   40733004
# 19  pmid-12513699   75478009
# 20  pmid-16859512   75934005
# 21  pmid-19728864  417163006
# 22  pmid-19728864   40733004
# 23  pmid-17570159  173300003
# 24  pmid-16162287  417163006
# 25  pmid-19615098   39898005
# 26  pmid-21970639   75934005
# 27  pmid-21970639  373673007
# 29  pmid-20205899   87858002
# 30  pmid-20467566  399981008
# 31  pmid-20467566  127326005
# 32  pmid-21645423  123946008
# 33  pmid-21645423  414029004
# 35  pmid-16185359  123946008
# 37  pmid-21929778  362975008
# 38  pmid-21929778  123946008
# 39  pmid-21929778  414032001
# 40  pmid-20184780  362975008
# 42  pmid-17961234   75934005
# 43  pmid-12946280  414029004
# 45  pmid-16207330  123946008
# 46  pmid-20226025   40733004
# 48  pmid-18803862  123946008
# 49  pmid-18803862   74732009
# 51  pmid-22085420  123946008
# 53  pmid-15663781  123946008
# 54  pmid-15663781  278919001
# 55  pmid-21943017  116223007
# 56  pmid-19946529  422400008
# 57  pmid-19772665  127326005
# 58  pmid-19772665  123946008
# 59  pmid-20043852   75934005
# 61  pmid-18681960  123946008
# 62  pmid-19575801   74732009
# 64  pmid-15327694  429040005
# 65  pmid-17391520   40733004
# 66  pmid-16343344   74732009
# 67  pmid-21838922  362975008
# 68  pmid-21838922  417163006
# 69  pmid-19830000  123946008
# 70  pmid-19818129   75934005
# 71  pmid-21569511   75478009
#               ...        ...
#
# [31424 rows x 2 columns]

# %% [markdown]
# La frecuencia de conceptos se puede ver acontinuación.

# %%
anotacionesgrouped = anotaciones.groupby("conceptId").count()
listafrecuencia = pd.Series(anotacionesgrouped.conceptId)
listafrecuencia.sort()
listafrecuencia
# Out:
# conceptId
# 77434001     1
# 87118001     1
# 420721002    1
# 78885002     1
# 105620001    2
# 385494008    2
# 12456005     4
# 402693001    4
# 274134003    4
# 404177007    5
# 441456002    6
# 41969006     6
# 85983004     7
# 428794004    7
# 125670008    7
# ...
# 116223007     572
# 399981008     591
# 75478009      689
# 87858002      903
# 66091009      947
# 127326005     954
# 128139000    1005
# 414029004    1031
# 2704003      1032
# 362975008    1119
# 417163006    1661
# 74732009     2534
# 75934005     2799
# 40733004     3548
# 123946008    5724
# Name: conceptId, Length: 71, dtype: int64

# %% [markdown]
# Aquí se presentan los artículos que mas veces se anotaron

# %%
anotacionesgrouped = anotaciones.groupby("article_id").count()
articulosfrecuencia = pd.Series(anotacionesgrouped.article_id)
articulosfrecuencia.sort()
articulosfrecuencia
# Out:
# article_id
# pmcid-1386690    1
# pmid-19671131    1
# pmid-21496312    1
# pmid-19671138    1
# pmid-19671139    1
# pmid-19671141    1
# pmid-19671143    1
# pmid-19671146    1
# pmid-19671148    1
# pmid-19671155    1
# pmid-19671170    1
# pmid-19671171    1
# pmid-21496308    1
# pmid-19671189    1
# pmid-19671190    1
# ...
# pmid-19918351    5
# pmid-19918288    5
# pmid-21663626    5
# pmid-11299048    6
# pmid-21572804    6
# pmid-21747843    6
# pmid-21569519    6
# pmid-18237382    6
# pmid-20184679    6
# pmid-19519924    6
# pmid-19835640    6
# pmid-19918517    6
# pmid-17784967    8
# pmid-19881994    8
# pmid-20418986    8
# Name: article_id, Length: 23247, dtype: int64

# %% [markdown]
# Se van a verificar varias de las anotaciones hechas a los artículos verificando aquellas de mayor frecuencia, para lo cual cargaremos la lista de conceptos originales

# %%
originalannotations = pd.read_csv('annotations.csv')
mostfrequent = ["pmid-17784967", "pmid-19881994", "pmid-20418986"]
original = originalannotations[originalannotations.article_id.isin(mostfrequent)]
#processed = anotaciones[anotaciones.article_id.isin((mostfrequent))]
conceptos = pd.read_csv("conceptosDiseases.csv")
conceptos.rename(columns={'Concept':'conceptId'}, inplace=True)
#conceptos
pd.merge(original, conceptos, on = "conceptId")
# Out:
#        article_id  conceptId    weigth     icval  category  \
# 0   pmid-19881994   17796002  0.144712  1.000000  disorder
# 1   pmid-19881994  111001004  0.216275  0.848449  disorder
# 2   pmid-19881994  404164003  0.147510  0.989098  disorder
# 3   pmid-19881994   74578003  0.114843  0.995333  disorder
# 4   pmid-20418986   74578003  0.127003  0.995333  disorder
# 5   pmid-19881994   61003004  0.108611  0.943410  disorder
# 6   pmid-19881994  189099001  0.126231  1.000000  disorder
# 7   pmid-19881994   19726003  0.150935  0.986909  disorder
# 8   pmid-19881994    8214000  0.172212  1.000000  disorder
# 9   pmid-19881994   79268002  0.131707  1.000000  disorder
# 10  pmid-19881994   84625002  0.134074  0.992219  disorder
# 11  pmid-19881994   58588007  0.128727  0.939223  disorder
# 12  pmid-20418986   86142006  0.122736  0.955995  disorder
# 13  pmid-20418986  109787002  0.166916  0.997408  disorder
# 14  pmid-20418986  235048000  0.166916  1.000000  disorder
# 15  pmid-20418986  427617000  0.144480  0.943410  disorder
# 16  pmid-20418986  404167005  0.160034  1.000000  disorder
# 17  pmid-20418986  449780004  1.142678  1.000000  disorder
# 18  pmid-20418986  310701003  0.123052  0.921991  disorder
# 19  pmid-20418986   30731004  0.163129  1.000000  disorder
# 20  pmid-20418986  109769000  0.171799  1.000000  disorder
# 21  pmid-17784967   47270006  0.177605  0.959262  disorder
# 22  pmid-17784967   53165003  0.101835  0.856799  disorder
# 23  pmid-17784967  237785004  0.119430  0.916976  disorder
# 24  pmid-17784967   40930008  0.135796  0.862553  disorder
# 25  pmid-17784967  254965007  0.111813  1.000000  disorder
# 26  pmid-17784967   43153006  0.120989  0.981782  disorder
# 27  pmid-17784967   83728000  0.148513  1.000000  disorder
# 28  pmid-17784967   41299009  0.130164  1.000000  disorder
# 29  pmid-17784967   71677004  0.165138  0.695240  disorder
# 30  pmid-17784967   55807009  0.139339  0.997563  disorder
# 31  pmid-17784967   24867002  0.108860  1.000000  disorder
#
#                                    fullySpecifiedName  ConceptProcessed
# 0                   Transient acantholytic dermatosis         362975008
# 1                                          Gammopathy         414029004
# 2                         Necrobiotic xanthogranuloma         414026006
# 3                                Pyoderma gangrenosum         429040005
# 4                                Pyoderma gangrenosum         429040005
# 5                               Epidermolysis bullosa         362975008
# 6                                     Xanthogranuloma         414026006
# 7                           Cutis laxa, acquired type         362975008
# 8          Telangiectasia macularis eruptiva perstans          27624003
# 9   Polyneuropathy, organomegaly, endocrinopathy, ...         123946008
# 10              Acute febrile neutrophilic dermatosis         416113008
# 11                                         Cutis laxa          75934005
# 12                                         Pemphigoid         414029004
# 13          Inflammatory fibrous hyperplasia of mouth         128139000
# 14                           Orofacial granulomatosis         123946008
# 15  Aphthous ulceration of skin and/or mucous memb...         429040005
# 16                      Malakoplakia (involving skin)         414026006
# 17                                  Riga-Fede disease         429040005
# 18                                  Behcet's syndrome         281867008
# 19                                        Glossodynia         373673007
# 20                        Necrotizing sialometaplasia         417163006
# 21                                   Hypercortisolism         123946008
# 22                               Megaloblastic anemia         414022008
# 23                                     Hypoadrenalism         123946008
# 24                                     Hypothyroidism         123946008
# 25                             Pituitary macroadenoma         399981008
# 26                                           Myxedema         118654009
# 27          Polyglandular autoimmune syndrome, type 2         414029004
# 28                       Iatrogenic Cushing's disease          12456005
# 29           Injury due to exposure to external cause         417163006
# 30             Toxic diffuse goiter with exophthalmos         421976005
# 31                       Severe adrenal insufficiency         123946008
#
# [32 rows x 7 columns]

# %% [markdown]
# Así que hemos decidido revisar los artículos manualmente usando: http://www.ncbi.nlm.nih.gov/pmc/pmctopmid/ que nos permite buscar los artículo tanto por PMID como por PMCID o por DOI.

# %% [markdown]
# pmid-17784967: Attitude of medical students towards Early Clinical Exposure in learning endocrine physiology
# En este artículo es de observar que las anotaciones hechas se llevan a cabo tan solo por la correspondencia de una palabra con la ontología, cómo es el caso de "Toxic diffuse goiter with exophthalmos" cuando el artículo se refiere a hipertiroidismo en el exotálamo o es el caso de "Severe adrenal insufficiency" donde solo se mencionan aspectos suprarrenales. Es aun más interesante el caso de Hypercortisolism donde esta anotación fue hecha usando Cushing's syndrome como su generadora. Siendo esta la anotación con mayor tf-idf.
#
# pmid-20418986: RIGA-FEDE-LIKE DISEASE IN A 70 YEAR OLD WOMAN
# En este caso la anotación Riga-Fede disease cuyo peso es el mayor es la adecuada mientras las demas si aparecen pero solo son mencionadas para alimentar la discusión.
#
#
# pmid-19881994: A CASE OF MULTIPLE MYELOMA PRESENTING AS A BULLOUS DERMATOSIS
# En este caso se repite que multiples de las anotaciones simplemente son mencionadas pero no cómo diagnosis sino como referentes.

# %% [markdown]
# Para revisar el caso de articulos de baja anotación se verifica los conceptos originalmente anotados

# %%
original = originalannotations[originalannotations.article_id.isin(["pmid-19671131"])]
original
# Out:
#            article_id  conceptId    weigth     icval        category  \
# 135569  pmid-19671131  256674009  0.250947  0.987415       substance
# 135570  pmid-19671131    5987007  0.368316  1.000000         finding
# 135571  pmid-19671131   10052007  0.118872  0.701501  body structure
# 135572  pmid-19671131   80382003  0.481610  0.677414       substance
# 135573  pmid-19671131  282750008  0.484457  1.000000        disorder
# 135574  pmid-19671131  248226002  0.103023  1.000000         finding
# 135575  pmid-19671131    1086007  0.134722  0.680616  body structure
# 135576  pmid-19671131   31979005  0.240368  0.844803       substance
# 135577  pmid-19671131   70256003  0.232647  0.846291         finding
#
#                    fullySpecifiedName
# 135569                            Fat
# 135570               Recognition odor
# 135571                 Male structure
# 135572                    Hydrocarbon
# 135573                    Knocked out
# 135574              Being out of body
# 135575               Female structure
# 135576                     Fatty acid
# 135577  Finding of sexual intercourse
#
# [9 rows x 6 columns]

# %%
original = originalannotations[originalannotations.article_id.isin(["pmid-19671141"])]
original
# Out:
#           article_id  conceptId    weigth     icval        category  \
# 59798  pmid-19671141  302550007  0.491228  1.000000  body structure
# 59799  pmid-19671141   35806005  0.170795  0.997763  body structure
# 59800  pmid-19671141   45685007  0.185486  0.983378       procedure
# 59801  pmid-19671141    6217003  1.142016  0.997763  body structure
# 59802  pmid-19671141  422588002  0.311992  0.979190        disorder
# 59803  pmid-19671141  361355005  0.122759  1.000000  body structure
# 59804  pmid-19671141  233604007  0.162942  0.860057        disorder
# 59805  pmid-19671141   81011003  0.159099  1.000000       procedure
# 59806  pmid-19671141   15119000  0.127085  0.939427  body structure
# 59807  pmid-19671141   74761005  0.148870  0.994096  body structure
# 59808  pmid-19671141  178283002  0.358932  0.997408       procedure
#
#                              fullySpecifiedName
# 59798                               Entire neck
# 59799           Structure of postcricoid region
# 59800                   Radical neck dissection
# 59801              Structure of piriform recess
# 59802                      Aspiration pneumonia
# 59803                      Entire head and neck
# 59804                                 Pneumonia
# 59805                  Nasogastric tube removal
# 59806                 Accessory nerve structure
# 59807   Structure of ventricular fold of larynx
# 59808  Block dissection of cervical lymph nodes
#
# [11 rows x 6 columns]

# %% [markdown]
# ## Separación del conjunto de datos para entrenamiento y validación

listafrecuencias.sort()
listafrecuencias
# Out:
# Imagen
# 12178_2007_9001_Fig1_HTML.jpg    1
# 1743-422X-4-135-2.jpg            1
# 1743-422X-4-14-4.jpg             1
# 1743-422X-4-14-5.jpg             1
# 1743-422X-4-2-1.jpg              1
# 1743-422X-4-2-2.jpg              1
# 1743-422X-4-2-3.jpg              1
# 1743-422X-4-2-4.jpg              1
# 1743-422X-4-2-5.jpg              1
# 1743-422X-4-2-6.jpg              1
# 1743-422X-4-23-1.jpg             1
# 1743-422X-4-23-2.jpg             1
# 1743-422X-4-26-1.jpg             1
# 1743-422X-4-26-3.jpg             1
# 1743-422X-4-33-1.jpg             1
# ...
# 1757-1626-0002-0000007275-008.jpg    6
# IJD-53-83-g001.jpg                   6
# 1757-1626-0002-0000006609-1.jpg      6
# 1757-1626-0002-0000007275-002.jpg    6
# 1472-6920-7-30-3.jpg                 6
# ar2368-1.jpg                         6
# ar2669-1.jpg                         6
# ar2669-2.jpg                         6
# ar2669-4.jpg                         6
# 1472-6920-7-30-5.jpg                 7
# IJD-55-92-g003.jpg                   7
# IJD-55-92-g002.jpg                   7
# IJD-55-92-g001.jpg                   7
# 1472-6920-7-30-1.jpg                 8
# IJD-53-83-g002.jpg                   8
# Name: Imagen, Length: 64851, dtype: int64

# %% [markdown]
# ## Experimentación

# %% [markdown]
# Dentro del dataset de disease se crearon 3 experimentos. Los dos primeros pretender reutilizar las features obtenidas durante el entrenamiento de ImageNet y el tercer experimento pretende hacer un entrenamiento completo de las imágenes usadas en Disease.
#
# Las diferencias entre los dos primeros esquemas radica en los pesos asignados a cada capa:

# %% [raw]
# layers {
#   name: "conv2"
#   type: CONVOLUTION
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
# ...
#
# layers {
#   name: "conv2"
#   type: CONVOLUTION
#   blobs_lr: 0
#   blobs_lr: 0
#   weight_decay: 1
#   weight_decay: 0
# ...

# %% [markdown]
# Asi como en la penúltima capa Fully Connected:

# %% [raw]
# layers {
#   name: "fc8_t"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 71
# ...
#
# layers {
#   name: "fc8_t"
#   type: INNER_PRODUCT
#   blobs_lr: 10
#   blobs_lr: 20
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 71

# %% [markdown]
# A continuación podemos ver los resultados de Accuracy y Loss sobre el conjunto de validación, seguido de los resultados de Loss en entrenamiento para el primer esquema de experimentación.

# %%
a = Image(filename = 'figures_disease/accuracyFine1.png')
b = Image(filename = 'figures_disease/testLossFine1.png')
c = Image(filename = 'figures_disease/trainLossFine1.png')
for im in [a,b,c]:
    display(im)

# %% [markdown]
# Para el segundo esquema de entrenamiento se obtuvieron los siguientes resultados:

# %%
a = Image(filename = 'figures_disease/accuracyFine2.png')
b = Image(filename = 'figures_disease/testLossFine2.png')
c = Image(filename = 'figures_disease/trainLossFine2.png')
for im in [a,b,c]:
    display(im)

# %% [markdown]
# El ultimo esquema de entrenamiento contemplaba usar el mismo prototxt empleado para entrenar desde ceros una red neuronal, es decir en vez de cargar los pesos aprendidos por el modelo de ImageNet, se aprenderian los propios pesos. El train.prototxt usado es muy parecido al usado para entrenar ImageNet excepto por la salida de la penultima capa donde su valor debe ser 71. A continuación se presentan los resultados de accuracy y loss en validación y de loss en entrenamiento.

# %%
a = Image(filename = 'figures_disease/accuracyWhole.png')
b = Image(filename = 'figures_disease/testLossWhole.png')
c = Image(filename = 'figures_disease/trainLossWhole.png')
for im in [a,b,c]:
    display(im)

# %% [markdown]
# ## Visualizando filtros aprendidos

# %% [markdown]
# Para obtener una visión de qué está aprendiendo la red neuronal se han visualizado los filtros aprendidos por el segundo y tercer experimento.

# %%
plt.rcParams['figure.figsize'] = (10, 10)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
net = caffe.Classifier('caffe_models/alexnet_deploy.prototxt',
                       'caffe_models/alexnet_train_iter_112500')

# %%
net.set_phase_test()
net.set_mode_cpu()
# input preprocessing: 'data' is the name of the input blob == net.inputs[0]
#net.set_mean('data', np.load('caffe_models/imageclefdisease_mean.binaryproto'))  # ImageNet mean
#net.set_raw_scale('data', 255)  # the reference model operates on images in [0,255] range instead of [0,1]
net.set_channel_swap('data', (2,1,0))  # the reference model has channels in BGR order instead of RGB

# %%
scores = net.predict([caffe.io.load_image('caffe_models/IJD-53-83-g002.jpg')])

# %%
[(k, v.data.shape) for k, v in net.blobs.items()]
# Out:
# [('data', (10, 3, 227, 227)),
#  ('conv1', (10, 96, 55, 55)),
#  ('norm1', (10, 96, 55, 55)),
#  ('pool1', (10, 96, 27, 27)),
#  ('conv2', (10, 256, 27, 27)),
#  ('norm2', (10, 256, 27, 27)),
#  ('pool2', (10, 256, 13, 13)),
#  ('conv3', (10, 384, 13, 13)),
#  ('conv4', (10, 384, 13, 13)),
#  ('conv5', (10, 256, 13, 13)),
#  ('pool5', (10, 256, 6, 6)),
#  ('fc6', (10, 4096, 1, 1)),
#  ('fc7', (10, 4096, 1, 1)),
#  ('fc8', (10, 71, 1, 1)),
#  ('prob', (10, 71, 1, 1))]

# %%
[(k, v[0].data.shape) for k, v in net.params.items()]
# Out:
# [('conv1', (96, 3, 11, 11)),
#  ('conv2', (256, 48, 5, 5)),
#  ('conv3', (384, 256, 3, 3)),
#  ('conv4', (384, 192, 3, 3)),
#  ('conv5', (256, 192, 3, 3)),
#  ('fc6', (1, 1, 4096, 9216)),
#  ('fc7', (1, 1, 4096, 4096)),
#  ('fc8', (1, 1, 71, 4096))]

# %%
# take an array of shape (n, height, width) or (n, height, width, channels)
#  and visualize each (height, width) thing in a grid of size approx. sqrt(n) by sqrt(n)
def vis_square(data, padsize=1, padval=0):
    data -= data.min()
    data /= data.max()
    
    # force the number of filters to be square
    n = int(np.ceil(np.sqrt(data.shape[0])))
    padding = ((0, n ** 2 - data.shape[0]), (0, padsize), (0, padsize)) + ((0, 0),) * (data.ndim - 3)
    data = np.pad(data, padding, mode='constant', constant_values=(padval, padval))
    
    # tile the filters into an image
    data = data.reshape((n, n) + data.shape[1:]).transpose((0, 2, 1, 3) + tuple(range(4, data.ndim + 1)))
    data = data.reshape((n * data.shape[1], n * data.shape[3]) + data.shape[4:])
    
    plt.imshow(data)

# %%
# the parameters are a list of [weights, biases]
filters = net.params['conv1'][0].data
vis_square(filters.transpose(0, 2, 3, 1))

# %%
feat = net.blobs['conv1'].data[4, :36]
vis_square(feat, padval=1)

# %%
feat = net.blobs['prob'].data[4]
plt.plot(feat.flat)
